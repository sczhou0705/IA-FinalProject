# %%
import csv
from time import sleep
import json
import requests
from bs4 import BeautifulSoup
import re
import s3fs
import pandas as pd

# %%
def extract_salary_info(job_title, job_city):
    """The salary website has different url patterns."""
    # URL pattern 1
    template = 'https://www.salary.com/research/salary/posting/{}-salary/{}'

    # Build the url based on search criteria
    url = template.format(job_title, job_city) 
    # print(url)
    
    try:
        response = requests.get(url)
        if response.status_code != 200:
            # URL pattern 2
            template = 'https://www.salary.com/research/salary/alternate/{}-salary/{}'
            url = template.format(job_title, job_city)
            response = requests.get(url)
            if response.status_code != 200:
                # URL pattern 3
                template = 'https://www.salary.com/research/salary/benchmark/{}-salary/{}'
                url = template.format(job_title, job_city)
                response = requests.get(url)
                if response.status_code != 200:
                    return None
    except requests.exceptions.ConnectionError:
        return None
   
    # Parse the html and extract json data
    soup = BeautifulSoup(response.text, 'html.parser')
    pattern = re.compile(r'Occupation')
    script = soup.find('script', {'type': 'application/ld+json'}, text=pattern)
    json_raw = script.contents[0]
    json_data = json.loads(json_raw)

    # Extract salary data
    job_title = json_data['name']
    location = json_data['occupationLocation'][0]['name']
    description = json_data['description']

    ntile_10 = json_data['estimatedSalary'][0]['percentile10']
    ntile_25 = json_data['estimatedSalary'][0]['percentile25']
    ntile_50 = json_data['estimatedSalary'][0]['median']
    ntile_75 = json_data['estimatedSalary'][0]['percentile75']
    ntile_90 = json_data['estimatedSalary'][0]['percentile90']

    data = (job_title, location, description, ntile_10, ntile_25, ntile_50, ntile_75, ntile_90)
    return data

# %%
def main():
    job_titles = ['entry-data-analyst','data-scientist-i','machine-learning-engineer','business-intelligence-bi-developer',
              'entry-level-python-developer','ux-design-intern','data-architect-i','big-data-architect',
              'database-administrator-entry','Entry-Business-Systems-Analyst']

    # Get the list of largest us cities.
    # The csv file is saved in salary scraper file.
    with open('largest_cities.csv', newline='') as f:
        reader = csv.reader(f)
        cities = [city for row in reader for city in row]
        #print（cities)
    # Extract salary data for corresponding city
    salary_data = []
    for city in cities:
        for job_title in job_titles:
            result = extract_salary_info(job_title, city)
            if result:
                salary_data.append(result)
                sleep(0.5)
            
    # Save data to csv file
    #with open('salary-results.csv', 'w', newline='', encoding='utf-8') as f:
        #writer = csv.writer(f)
        #writer.writerow(['Title','Location', 'Description', 'nTile10', 'nTile25', 'nTile50', 'nTile75', 'nTile90'])
        #writer.writerows(salary_data)
        
    return salary_data

# %%
# Call function
main()
# Out:
# [('Entry Data Analyst',
#   'New York, NY',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '59417',
#   '66701',
#   '74701',
#   '85201',
#   '94761'),
#  ('Data Scientist I',
#   'New York, NY',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '71385',
#   '79225',
#   '87835',
#   '94930',
#   '101390'),
#  ('Machine Learning Engineer',
#   'New York, NY',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '120959',
#   '133726',
#   '147749',
#   '163993',
#   '178782'),
#  ('Business Intelligence (BI) Developer',
#   'New York, NY',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '84662',
#   '96747',
#   '110021',
#   '124339',
#   '137376'),
#  ('Entry Level Python Developer',
#   'New York, NY',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '86240',
#   '96633',
#   '108048',
#   '123254',
#   '137098'),
#  ('UX Design Intern',
#   'New York, NY',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '70071',
#   '81053',
#   '93115',
#   '102323',
#   '110707'),
#  ('Data Architect I',
#   'New York, NY',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '56510',
#   '76862',
#   '99216',
#   '121634',
#   '142045'),
#  ('Big Data Architect',
#   'New York, NY',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '142697',
#   '160526',
#   '180108',
#   '209540',
#   '236337'),
#  ('Database Administrator - Entry',
#   'New York, NY',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '63651',
#   '72300',
#   '81800',
#   '94800',
#   '106636'),
#  ('Entry Business Systems Analyst',
#   'New York, NY',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '59876',
#   '67260',
#   '75370',
#   '84300',
#   '92430'),
#  ('Entry Data Analyst',
#   'Chicago, IL',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '52337',
#   '58801',
#   '65901',
#   '75101',
#   '83477'),
#  ('Data Scientist I',
#   'Chicago, IL',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '62952',
#   '69866',
#   '77459',
#   '83716',
#   '89413'),
#  ('Machine Learning Engineer',
#   'Chicago, IL',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '106670',
#   '117929',
#   '130295',
#   '144620',
#   '157662'),
#  ('Business Intelligence (BI) Developer',
#   'Chicago, IL',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '74661',
#   '85318',
#   '97024',
#   '109651',
#   '121147'),
#  ('Entry Level Python Developer',
#   'Chicago, IL',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '76052',
#   '85218',
#   '95284',
#   '108694',
#   '120903'),
#  ('UX Design Intern',
#   'Chicago, IL',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '61794',
#   '71478',
#   '82115',
#   '90236',
#   '97629'),
#  ('Data Architect I',
#   'Chicago, IL',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '49834',
#   '67782',
#   '87495',
#   '107265',
#   '125265'),
#  ('Big Data Architect',
#   'Chicago, IL',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '125840',
#   '141563',
#   '158832',
#   '184787',
#   '208418'),
#  ('Database Administrator - Entry',
#   'Chicago, IL',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '56152',
#   '63800',
#   '72200',
#   '83700',
#   '94170'),
#  ('Entry Business Systems Analyst',
#   'Chicago, IL',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '52800',
#   '59310',
#   '66460',
#   '74340',
#   '81514'),
#  ('Entry Data Analyst',
#   'Woodbridge, NJ',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '55373',
#   '62201',
#   '69701',
#   '79401',
#   '88232'),
#  ('Data Scientist I',
#   'Woodbridge, NJ',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '66579',
#   '73890',
#   '81921',
#   '88538',
#   '94563'),
#  ('Machine Learning Engineer',
#   'Woodbridge, NJ',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '112815',
#   '124722',
#   '137801',
#   '152951',
#   '166744'),
#  ('Business Intelligence (BI) Developer',
#   'Woodbridge, NJ',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '78962',
#   '90233',
#   '102613',
#   '115967',
#   '128126'),
#  ('Entry Level Python Developer',
#   'Woodbridge, NJ',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '80433',
#   '90126',
#   '100773',
#   '114955',
#   '127867'),
#  ('UX Design Intern',
#   'Woodbridge, NJ',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '65353',
#   '75595',
#   '86845',
#   '95434',
#   '103253'),
#  ('Data Architect I',
#   'Woodbridge, NJ',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '52705',
#   '71686',
#   '92535',
#   '113444',
#   '132481'),
#  ('Big Data Architect',
#   'Woodbridge, NJ',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '133089',
#   '149717',
#   '167981',
#   '195432',
#   '220424'),
#  ('Database Administrator - Entry',
#   'Woodbridge, NJ',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '59488',
#   '67500',
#   '76300',
#   '88500',
#   '99607'),
#  ('Entry Business Systems Analyst',
#   'Woodbridge, NJ',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '55847',
#   '62730',
#   '70290',
#   '78620',
#   '86204'),
#  ('Entry Data Analyst',
#   'San Francisco, CA',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '61744',
#   '69301',
#   '77601',
#   '88501',
#   '98425'),
#  ('Data Scientist I',
#   'San Francisco, CA',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '74174',
#   '82320',
#   '91267',
#   '98639',
#   '105351'),
#  ('Machine Learning Engineer',
#   'San Francisco, CA',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '125685',
#   '138951',
#   '153521',
#   '170400',
#   '185766'),
#  ('Business Intelligence (BI) Developer',
#   'San Francisco, CA',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '87970',
#   '100527',
#   '114319',
#   '129197',
#   '142743'),
#  ('Entry Level Python Developer',
#   'San Francisco, CA',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '89609',
#   '100408',
#   '112269',
#   '128069',
#   '142454'),
#  ('UX Design Intern',
#   'San Francisco, CA',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '72809',
#   '84220',
#   '96753',
#   '106321',
#   '115032'),
#  ('Data Architect I',
#   'San Francisco, CA',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '58717',
#   '79865',
#   '103092',
#   '126386',
#   '147594'),
#  ('Big Data Architect',
#   'San Francisco, CA',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '148272',
#   '166797',
#   '187145',
#   '217727',
#   '245570'),
#  ('Database Administrator - Entry',
#   'San Francisco, CA',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '66087',
#   '75100',
#   '85000',
#   '98600',
#   '110982'),
#  ('Entry Business Systems Analyst',
#   'San Francisco, CA',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '62224',
#   '69890',
#   '78310',
#   '87590',
#   '96039'),
#  ('Entry Data Analyst',
#   'Los Angeles, CA',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '55873',
#   '62701',
#   '70201',
#   '80101',
#   '89114'),
#  ('Data Scientist I',
#   'Los Angeles, CA',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '67112',
#   '74482',
#   '82577',
#   '89247',
#   '95320'),
#  ('Machine Learning Engineer',
#   'Los Angeles, CA',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '113718',
#   '125720',
#   '138904',
#   '154175',
#   '168079'),
#  ('Business Intelligence (BI) Developer',
#   'Los Angeles, CA',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '79594',
#   '90955',
#   '103434',
#   '116895',
#   '129151'),
#  ('Entry Level Python Developer',
#   'Los Angeles, CA',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '81077',
#   '90848',
#   '101579',
#   '115875',
#   '128890'),
#  ('UX Design Intern',
#   'Los Angeles, CA',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '65876',
#   '76201',
#   '87540',
#   '96197',
#   '104079'),
#  ('Data Architect I',
#   'Los Angeles, CA',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '53126',
#   '72260',
#   '93276',
#   '114352',
#   '133541'),
#  ('Big Data Architect',
#   'Los Angeles, CA',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '134154',
#   '150916',
#   '169325',
#   '196996',
#   '222188'),
#  ('Database Administrator - Entry',
#   'Los Angeles, CA',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '59897',
#   '68000',
#   '76900',
#   '89200',
#   '100399'),
#  ('Entry Business Systems Analyst',
#   'Los Angeles, CA',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '56292',
#   '63230',
#   '70850',
#   '79250',
#   '86898'),
#  ('Entry Data Analyst',
#   'Bridgeport, CT',
#   'The Entry Data Analyst researches best practices and supports developing the solutions and recommendations for the current business operations. Performs routine business analysis using various techniques, e.g. statistical analysis, explanatory and predictive modeling, data mining. Being an Entry Data Analyst may provide business data interpretation. May work with the internal or external client to identify analytical requirements. In addition, Entry Data Analyst may help to produce ad hoc data and reports. May assist in developing or implementing systems to capture business operation information. Requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. Being an Entry Data Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Data Analyst typically requires 0-2 years of related experience.',
#   '56173',
#   '63001',
#   '70501',
#   '80401',
#   '89414'),
#  ('Data Scientist I',
#   'Bridgeport, CT',
#   'Data Scientist I identifies business trends and problems through complex big data analysis. Interprets results from multiple sources using a variety of techniques, ranging from simple data aggregation via statistical analysis to complex data mining independently. Being a Data Scientist I designs, develops and implements the most valuable business solutions for the organization. Prepares big data, implements data models and develops database to support the business solutions. Additionally, Data Scientist I may require an advanced degree. Typically reports to a manager. The Data Scientist I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Data Scientist I typically requires 0-2 years of related experience.',
#   '67409',
#   '74812',
#   '82943',
#   '89643',
#   '95743'),
#  ('Machine Learning Engineer',
#   'Bridgeport, CT',
#   'Machine learning (ML) is the scientific study of algorithms and statistical models that computer systems use to effectively perform a specific task without using explicit instructions, relying on patterns and inference instead. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model of sample data, known as &quot;training data&quot;, in order to make predictions or decisions without being explicitly programmed to perform the task.:2 Machine learning algorithms are used in a wide variety of applications, such as email filtering, and computer vision, where it is infeasible to develop an algorithm of specific instructions for performing the task. Machine learning is closely related to computational statistics, which focuses on making predictions using computers. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a field of study within machine learning, and focuses on exploratory data analysis through unsupervised learning. In its application across business problems, machine learning is also referred to as predictive analytics.',
#   '114223',
#   '126278',
#   '139520',
#   '154859',
#   '168825'),
#  ('Business Intelligence (BI) Developer',
#   'Bridgeport, CT',
#   'Business Intelligence Specialist III creates reports, visualizations, dashboards, and metrics that provide business insight and aid business decision-making. Uses querying languages like SQL, scripting languages like R or Python, and other tools like Tableau or Excel to produce reports and perform meaningful quantitative or qualitative analyses addressing impactful business issues or questions. Being a Business Intelligence Specialist III combines these reports with subject-matter expertise to deliver coherent, insightful takeaways and advice. Collaborates with project stakeholders to better understand valuable objectives and KPIs and to design relevant reports and dashboards. Additionally, Business Intelligence Specialist III requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Business Intelligence Specialist III work is generally independent and collaborative in nature. Contributes to moderately complex aspects of a project. To be a Business Intelligence Specialist III typically requires 4-7 years of related experience.',
#   '79947',
#   '91359',
#   '103893',
#   '117414',
#   '129725'),
#  ('Entry Level Python Developer',
#   'Bridgeport, CT',
#   'Web Applications Developer I designs, develops, and maintains internal and external websites for an organization. Uses knowledge of common web development languages (e.g., HTML, Java, PHP, JSP, ASP.NET, Python, AJAX) to build and expand site functionality. Being a Web Applications Developer I creates and enhances the overall website appearance using graphic/multi-media design software and designs site navigation that is clear and easy to understand. Ensures sites remain scalable while complying with performance and security standards. Additionally, Web Applications Developer I updates site content based on input from marketing and documents changes in source code. Typically requires a bachelor&#39;s degree in a related area. Typically reports to a manager. The Web Applications Developer I work is closely managed. Works on projects/matters of limited complexity in a support role. To be a Web Applications Developer I typically requires 0-2 years of related experience.',
#   '81437',
#   '91251',
#   '102030',
#   '116389',
#   '129463'),
#  ('UX Design Intern',
#   'Bridgeport, CT',
#   'UI/Usability Designer II applies user-centered design principles to improve the workflow, expand the functionality, and enhance the visual appeal of websites and mobile apps. Gathers requirements from users and stakeholders, defines information architecture, creates sample user personas, and documents user workflow. Being an UI/Usability Designer II designs wireframes, mockups, and prototypes. Applies the results from user research and usability testing to create new features and improve current features. Additionally, UI/Usability Designer II requires knowledge of HTML, JavaScript, Lineto and FLASH. May perform user research, usability testing, or facilitate focus groups. May require familiarity with various graphic design software packages. Typically requires a bachelor&#39;s degree in area of specialty. Typically reports to a supervisor or manager. The UI/Usability Designer II occasionally directed in several aspects of the work. Gaining exposure to some of the complex tasks within the job function. To be an UI/Usability Designer II typically requires 2-4 years of related experience.',
#   '66169',
#   '76539',
#   '87929',
#   '96624',
#   '104541'),
#  ('Data Architect I',
#   'Bridgeport, CT',
#   'Data Architect I designs and builds relational databases for data storage or processing. Develops strategies for warehouse implementation, data acquisition and access, and data archiving and recovery. Being a Data Architect I builds data models and defines the structure, attributes and nomenclature of data elements. May evaluate new data sources for adherence to the organization&#39;s quality standards and ease of integration. Additionally, Data Architect I typically requires a bachelor&#39;s degree. Typically reports to a supervisor or manager. The Data Architect I works on projects/matters of limited complexity in a support role. Work is closely managed. To be a Data Architect I typically requires 0-2 years of related experience.',
#   '53362',
#   '72581',
#   '93690',
#   '114860',
#   '134134'),
#  ('Big Data Architect',
#   'Bridgeport, CT',
#   'A data architect is a practitioner of data architecture, an information technology discipline concerned with designing, creating, deploying and managing an organization&#39;s data architecture. Data architects define how the data will be stored, consumed, integrated and managed by different data entities and IT systems, as well as any applications using or processing that data in some way.  It is closely allied with business architecture and is considered to be one of the four domains of enterprise architecture.',
#   '134750',
#   '151585',
#   '170077',
#   '197870',
#   '223174'),
#  ('Database Administrator - Entry',
#   'Bridgeport, CT',
#   'The Database Administrator - Entry implements and monitors database access and configurations. Administers and maintains the company database and data warehouses. Being a Database Administrator - Entry performs database recovery and back-up. Resolves database performance and capacity issues. In addition, Database Administrator - Entry may involve in capacity planning, and some development work. May require a bachelor&#39;s degree or its equivalent. Typically reports to a manager. Being a Database Administrator - Entry works on projects/matters of limited complexity in a support role. Work is closely managed. Working as a Database Administrator - Entry typically requires 0-2 years of related experience.',
#   '60106',
#   '68300',
#   '77300',
#   '89600',
#   '100799'),
#  ('Entry Business Systems Analyst',
#   'Bridgeport, CT',
#   'The Entry Business Systems Analyst documents system requirements, defines scope and objectives, and assists in the creation of system specifications that drive system development and implementation. Reviews, analyzes, and evaluates user needs to create systems solutions that support overall business strategies. Being an Entry Business Systems Analyst typically requires a bachelor&#39;s degree or its equivalent. Incumbents function as a liaison between IT and users and have both business and technical expertise. In addition, Entry Business Systems Analyst typically reports to a manager. Being an Entry Business Systems Analyst works on projects/matters of limited complexity in a support role. Work is closely managed. Working as an Entry Business Systems Analyst typically requires 0-2 years of related experience.',
#   '56536',
#   '63510',
#   '71170',
#   '79600',
#   '87275')]

# %%
salary_data = main()

# %%
df = pd.DataFrame(salary_data,columns = [['Title','Location', 'Description', 'nTile10', 'nTile25', 'nTile50', 'nTile75', 'nTile90']])
df
# Out:
#                                    Title           Location  \
# 0                     Entry Data Analyst       New York, NY
# 1                       Data Scientist I       New York, NY
# 2              Machine Learning Engineer       New York, NY
# 3   Business Intelligence (BI) Developer       New York, NY
# 4           Entry Level Python Developer       New York, NY
# 5                       UX Design Intern       New York, NY
# 6                       Data Architect I       New York, NY
# 7                     Big Data Architect       New York, NY
# 8         Database Administrator - Entry       New York, NY
# 9         Entry Business Systems Analyst       New York, NY
# 10                    Entry Data Analyst        Chicago, IL
# 11                      Data Scientist I        Chicago, IL
# 12             Machine Learning Engineer        Chicago, IL
# 13  Business Intelligence (BI) Developer        Chicago, IL
# 14          Entry Level Python Developer        Chicago, IL
# 15                      UX Design Intern        Chicago, IL
# 16                      Data Architect I        Chicago, IL
# 17                    Big Data Architect        Chicago, IL
# 18        Database Administrator - Entry        Chicago, IL
# 19        Entry Business Systems Analyst        Chicago, IL
# 20                    Entry Data Analyst     Woodbridge, NJ
# 21                      Data Scientist I     Woodbridge, NJ
# 22             Machine Learning Engineer     Woodbridge, NJ
# 23  Business Intelligence (BI) Developer     Woodbridge, NJ
# 24          Entry Level Python Developer     Woodbridge, NJ
# 25                      UX Design Intern     Woodbridge, NJ
# 26                      Data Architect I     Woodbridge, NJ
# 27                    Big Data Architect     Woodbridge, NJ
# 28        Database Administrator - Entry     Woodbridge, NJ
# 29        Entry Business Systems Analyst     Woodbridge, NJ
# 30                    Entry Data Analyst  San Francisco, CA
# 31                      Data Scientist I  San Francisco, CA
# 32             Machine Learning Engineer  San Francisco, CA
# 33  Business Intelligence (BI) Developer  San Francisco, CA
# 34          Entry Level Python Developer  San Francisco, CA
# 35                      UX Design Intern  San Francisco, CA
# 36                      Data Architect I  San Francisco, CA
# 37                    Big Data Architect  San Francisco, CA
# 38        Database Administrator - Entry  San Francisco, CA
# 39        Entry Business Systems Analyst  San Francisco, CA
# 40                    Entry Data Analyst    Los Angeles, CA
# 41                      Data Scientist I    Los Angeles, CA
# 42             Machine Learning Engineer    Los Angeles, CA
# 43  Business Intelligence (BI) Developer    Los Angeles, CA
# 44          Entry Level Python Developer    Los Angeles, CA
# 45                      UX Design Intern    Los Angeles, CA
# 46                      Data Architect I    Los Angeles, CA
# 47                    Big Data Architect    Los Angeles, CA
# 48        Database Administrator - Entry    Los Angeles, CA
# 49        Entry Business Systems Analyst    Los Angeles, CA
# 50                    Entry Data Analyst     Bridgeport, CT
# 51                      Data Scientist I     Bridgeport, CT
# 52             Machine Learning Engineer     Bridgeport, CT
# 53  Business Intelligence (BI) Developer     Bridgeport, CT
# 54          Entry Level Python Developer     Bridgeport, CT
# 55                      UX Design Intern     Bridgeport, CT
# 56                      Data Architect I     Bridgeport, CT
# 57                    Big Data Architect     Bridgeport, CT
# 58        Database Administrator - Entry     Bridgeport, CT
# 59        Entry Business Systems Analyst     Bridgeport, CT
#
#                                           Description nTile10 nTile25 nTile50  \
# 0   The Entry Data Analyst researches best practic...   59417   66701   74701
# 1   Data Scientist I identifies business trends an...   71385   79225   87835
# 2   Machine learning (ML) is the scientific study ...  120959  133726  147749
# 3   Business Intelligence Specialist III creates r...   84662   96747  110021
# 4   Web Applications Developer I designs, develops...   86240   96633  108048
# 5   UI/Usability Designer II applies user-centered...   70071   81053   93115
# 6   Data Architect I designs and builds relational...   56510   76862   99216
# 7   A data architect is a practitioner of data arc...  142697  160526  180108
# 8   The Database Administrator - Entry implements ...   63651   72300   81800
# 9   The Entry Business Systems Analyst documents s...   59876   67260   75370
# 10  The Entry Data Analyst researches best practic...   52337   58801   65901
# 11  Data Scientist I identifies business trends an...   62952   69866   77459
# 12  Machine learning (ML) is the scientific study ...  106670  117929  130295
# 13  Business Intelligence Specialist III creates r...   74661   85318   97024
# 14  Web Applications Developer I designs, develops...   76052   85218   95284
# 15  UI/Usability Designer II applies user-centered...   61794   71478   82115
# 16  Data Architect I designs and builds relational...   49834   67782   87495
# 17  A data architect is a practitioner of data arc...  125840  141563  158832
# 18  The Database Administrator - Entry implements ...   56152   63800   72200
# 19  The Entry Business Systems Analyst documents s...   52800   59310   66460
# 20  The Entry Data Analyst researches best practic...   55373   62201   69701
# 21  Data Scientist I identifies business trends an...   66579   73890   81921
# 22  Machine learning (ML) is the scientific study ...  112815  124722  137801
# 23  Business Intelligence Specialist III creates r...   78962   90233  102613
# 24  Web Applications Developer I designs, develops...   80433   90126  100773
# 25  UI/Usability Designer II applies user-centered...   65353   75595   86845
# 26  Data Architect I designs and builds relational...   52705   71686   92535
# 27  A data architect is a practitioner of data arc...  133089  149717  167981
# 28  The Database Administrator - Entry implements ...   59488   67500   76300
# 29  The Entry Business Systems Analyst documents s...   55847   62730   70290
# 30  The Entry Data Analyst researches best practic...   61744   69301   77601
# 31  Data Scientist I identifies business trends an...   74174   82320   91267
# 32  Machine learning (ML) is the scientific study ...  125685  138951  153521
# 33  Business Intelligence Specialist III creates r...   87970  100527  114319
# 34  Web Applications Developer I designs, develops...   89609  100408  112269
# 35  UI/Usability Designer II applies user-centered...   72809   84220   96753
# 36  Data Architect I designs and builds relational...   58717   79865  103092
# 37  A data architect is a practitioner of data arc...  148272  166797  187145
# 38  The Database Administrator - Entry implements ...   66087   75100   85000
# 39  The Entry Business Systems Analyst documents s...   62224   69890   78310
# 40  The Entry Data Analyst researches best practic...   55873   62701   70201
# 41  Data Scientist I identifies business trends an...   67112   74482   82577
# 42  Machine learning (ML) is the scientific study ...  113718  125720  138904
# 43  Business Intelligence Specialist III creates r...   79594   90955  103434
# 44  Web Applications Developer I designs, develops...   81077   90848  101579
# 45  UI/Usability Designer II applies user-centered...   65876   76201   87540
# 46  Data Architect I designs and builds relational...   53126   72260   93276
# 47  A data architect is a practitioner of data arc...  134154  150916  169325
# 48  The Database Administrator - Entry implements ...   59897   68000   76900
# 49  The Entry Business Systems Analyst documents s...   56292   63230   70850
# 50  The Entry Data Analyst researches best practic...   56173   63001   70501
# 51  Data Scientist I identifies business trends an...   67409   74812   82943
# 52  Machine learning (ML) is the scientific study ...  114223  126278  139520
# 53  Business Intelligence Specialist III creates r...   79947   91359  103893
# 54  Web Applications Developer I designs, develops...   81437   91251  102030
# 55  UI/Usability Designer II applies user-centered...   66169   76539   87929
# 56  Data Architect I designs and builds relational...   53362   72581   93690
# 57  A data architect is a practitioner of data arc...  134750  151585  170077
# 58  The Database Administrator - Entry implements ...   60106   68300   77300
# 59  The Entry Business Systems Analyst documents s...   56536   63510   71170
#
#    nTile75 nTile90
# 0    85201   94761
# 1    94930  101390
# 2   163993  178782
# 3   124339  137376
# 4   123254  137098
# 5   102323  110707
# 6   121634  142045
# 7   209540  236337
# 8    94800  106636
# 9    84300   92430
# 10   75101   83477
# 11   83716   89413
# 12  144620  157662
# 13  109651  121147
# 14  108694  120903
# 15   90236   97629
# 16  107265  125265
# 17  184787  208418
# 18   83700   94170
# 19   74340   81514
# 20   79401   88232
# 21   88538   94563
# 22  152951  166744
# 23  115967  128126
# 24  114955  127867
# 25   95434  103253
# 26  113444  132481
# 27  195432  220424
# 28   88500   99607
# 29   78620   86204
# 30   88501   98425
# 31   98639  105351
# 32  170400  185766
# 33  129197  142743
# 34  128069  142454
# 35  106321  115032
# 36  126386  147594
# 37  217727  245570
# 38   98600  110982
# 39   87590   96039
# 40   80101   89114
# 41   89247   95320
# 42  154175  168079
# 43  116895  129151
# 44  115875  128890
# 45   96197  104079
# 46  114352  133541
# 47  196996  222188
# 48   89200  100399
# 49   79250   86898
# 50   80401   89414
# 51   89643   95743
# 52  154859  168825
# 53  117414  129725
# 54  116389  129463
# 55   96624  104541
# 56  114860  134134
# 57  197870  223174
# 58   89600  100799
# 59   79600   87275

# %%
###LOAD THE FILE INTO S3####
# prepare csv file name   
pathname = 'ia-final-deployment/'#specify location of s3:/{my-bucket}/
filenames = f"{pathname}salary_data.csv" #name of the filepath and csv file

#encoding must be adjusted to accommodate abnormal characters. Use s3fs to write to S3 bucket
byte_encoded_df = df.to_csv(None, index=False).encode() #encodes file as binary
s3 = s3fs.S3FileSystem(anon=False)
with s3.open(filenames, 'wb') as file:
    file.write(byte_encoded_df) #writes byte-encoded file to s3 location

#print success message
print("Successfull uploaded file to location:"+str(filenames))
# Out:
# Successfull uploaded file to location:ia-final-deployment/salary_data.csv
